# %% [markdown]
# # HOME ASSIGNMENT #5: BIGQUERY SQL & PYTHON PANDAS
#
# **Mục đích của bài Assignment**
# > *  Upload Data từ Google Spreadsheet lên BigQuery và thao tác data với SQL
# *  Thao tác với data bằng Pandas
# *   `[Optional]` Data Visualization on Python
#
# **Các kiến thức áp dụng**
# * Slack API, JSON to DataFrame
# * Google Spreadsheet to BigQuery
# * SQL
# * Python Pandas
#
# **Lời Khuyên**
# * Đây là bài tập nhẹ nhàng hơn các tuần trước
# * Các bạn dành thời gian ôn lại và xâu chuỗi kiến thức

# %% [markdown]
# # TODO 1: BIGQUERY & SQL
# * Làm theo Lab của Week 5: [HERE](https://anhdang.gitbook.io/datacracy/atom/5-sql-and-database-design/5.2-lab-upload-data-tu-google-sheet-to-bigquery)

# %%
import requests #-> Để gọi API
import re #-> Để xử lý data dạng string
from datetime import datetime as dt #-> Để xử lý data dạng datetime
import gspread #-> Để update data lên Google Spreadsheet
from gspread_dataframe import set_with_dataframe #-> Để update data lên Google Spreadsheet
import pandas as pd #-> Để update data dạng bản
import json 
from oauth2client.service_account import ServiceAccountCredentials #-> Để nhập Google Spreadsheet Credentials
import os

# %%
with open('env_variable.json', 'r') as j:
    json_data = json.load(j)

# %%
os.environ['SLACK_BEARER_TOKEN'] = json_data['SLACK_BEARER_TOKEN']

# %%
## Gọi API từ Endpoints (Input - Token được đưa vào Headers)
## Challenge: Thử gọi API này bằng Postman
endpoint = "https://slack.com/api/users.list"
headers = {"Authorization": "Bearer {}".format(json_data['SLACK_BEARER_TOKEN'])}
response_json = requests.post(endpoint, headers=headers).json() 
user_dat = response_json['members']

## Convert to CSV
user_dict = {'user_id':[],'name':[],'display_name':[],'real_name':[],'title':[],'is_bot':[]}
for i in range(len(user_dat)):
  user_dict['user_id'].append(user_dat[i]['id'])
  user_dict['name'].append(user_dat[i]['name'])
  user_dict['display_name'].append(user_dat[i]['profile']['display_name'])
  user_dict['real_name'].append(user_dat[i]['profile']['real_name_normalized'])
  user_dict['title'].append(user_dat[i]['profile']['title'])
  user_dict['is_bot'].append(user_dat[i]['is_bot'])

user_df = pd.DataFrame(user_dict) 
user_df = user_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
user_df.head()
# Out:
#        user_id               name       display_name           real_name  \
# 0    USLACKBOT           slackbot           Slackbot            Slackbot
# 1  U01AT4T75JB     loclexuan26392        Loc Le Xuan         Loc Le Xuan
# 2  U01AVDY7JET           locle.ds        Loc Le Xuan         Loc Le Xuan
# 3  U01BE2PR6LU     maianhdang.ftu                MAD  Dặng Huỳnh Mai Anh
# 4  U01C48T7S1J  huyenhoang.design  Thanh Huyen Hoang   Thanh Huyen Hoang
#
#                 title  is_bot
# 0                 NaN   False
# 1                 NaN   False
# 2                 NaN   False
# 3  Technical Contents   False
# 4                 NaN   False

# %%
msg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        234 non-null    object
#  1   msg_id            234 non-null    object
#  2   msg_ts            234 non-null    datetime64[ns]
#  3   user_id           234 non-null    object
#  4   latest_reply      234 non-null    datetime64[ns]
#  5   reply_user_count  234 non-null    int64
#  6   reply_users       234 non-null    object
#  7   github_link       117 non-null    object
# dtypes: datetime64[ns](2), int64(1), object(5)
# memory usage: 14.8+ KB

# %%
# (1) Code để pull Slack Data
# 2. LIST OF SLACK CHANNELS

endpoint2 = "https://slack.com/api/conversations.list"
data = {'types': 'public_channel,private_channel'} # -> CHECK: API Docs https://api.slack.com/methods/conversations.list/test
response_json = requests.post(endpoint2, headers=headers, data=data).json() 
channel_dat = response_json['channels']

channel_dict = {'channel_id':[], 'channel_name':[], 'is_channel':[],'creator':[],'created_at':[],'topics':[],'purpose':[],'num_members':[]}
for i in range(len(channel_dat)):
    channel_dict['channel_id'].append(channel_dat[i]['id'])
    channel_dict['channel_name'].append(channel_dat[i]['name'])
    channel_dict['is_channel'].append(channel_dat[i]['is_channel'])
    channel_dict['creator'].append(channel_dat[i]['creator'])
    channel_dict['created_at'].append(dt.fromtimestamp(float(channel_dat[i]['created'])))
    channel_dict['topics'].append(channel_dat[i]['topic']['value'])
    channel_dict['purpose'].append(channel_dat[i]['purpose']['value'])
    channel_dict['num_members'].append(channel_dat[i]['num_members'])

channel_df = pd.DataFrame(channel_dict) 
channel_df = channel_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
channel_df.head()
# Out:
#     channel_id      channel_name  is_channel      creator          created_at  \
# 0  C01B4PVGLVB           general        True  U01BE2PR6LU 2020-09-23 17:25:03
# 1  C01BYH7JHB5          contents        True  U01BE2PR6LU 2020-10-05 14:28:09
# 2  C01CAMNCJJV   branding-design        True  U01AVDY7JET 2020-10-05 10:16:30
# 3  C01U6P7LZ8F  atom-assignment1        True  U01BE2PR6LU 2021-04-17 14:00:04
# 4  C01UL6K1C7L        atom-week1        True  U01BE2PR6LU 2021-04-17 00:44:32
#
#                                               topics  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Assigment#1 - Python Basics &amp; Spreadsheet ...
# 4  TOPIC: Data Strategy. Metrics Design. Spreadsh...
#
#                                              purpose  num_members
# 0  This is the one channel that will always inclu...           64
# 1                                                NaN           12
# 2                                                NaN            9
# 3  Where learners submit assignments and give rev...           44
# 4  TOPIC: Data Strategy. Metrics Design. Spreadsh...           43

# %%
endpoint3 = "https://slack.com/api/conversations.history"

msg_dict = {'channel_id':[],'msg_id':[], 'msg_ts':[], 'user_id':[], 'latest_reply':[],'reply_user_count':[],'reply_users':[],'github_link':[]}
for channel_id, channel_name in zip(channel_df['channel_id'], channel_df['channel_name']):
  print('Channel ID: {} - Channel Name: {}'.format(channel_id, channel_name))
  try:
    data = {"channel": channel_id} 
    response_json = requests.post(endpoint3, data=data, headers=headers).json()
    msg_ls = response_json['messages']
    for i in range(len(msg_ls)):
      if 'client_msg_id' in msg_ls[i].keys():
        msg_dict['channel_id'].append(channel_id)
        msg_dict['msg_id'].append(msg_ls[i]['client_msg_id'])
        msg_dict['msg_ts'].append(dt.fromtimestamp(float(msg_ls[i]['ts'])))
        msg_dict['latest_reply'].append(dt.fromtimestamp(float(msg_ls[i]['latest_reply'] if 'latest_reply' in msg_ls[i].keys() else 0))) ## -> No reply: 1970-01-01
        msg_dict['user_id'].append(msg_ls[i]['user'])
        msg_dict['reply_user_count'].append(msg_ls[i]['reply_users_count'] if 'reply_users_count' in msg_ls[i].keys() else 0)
        msg_dict['reply_users'].append(msg_ls[i]['reply_users'] if 'reply_users' in msg_ls[i].keys() else 0) 
        ## -> Censor message contains tokens
        text = msg_ls[i]['text']
        github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text)
        msg_dict['github_link'].append(github_link[0] if len(github_link) > 0 else np.nan)
  except:
    print('====> '+ str(response_json))
# Out:
# Channel ID: C01B4PVGLVB - Channel Name: general
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C01BYH7JHB5 - Channel Name: contents
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C01CAMNCJJV - Channel Name: branding-design
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C01U6P7LZ8F - Channel Name: atom-assignment1
# Channel ID: C01UL6K1C7L - Channel Name: atom-week1
# Channel ID: C01ULCHGN75 - Channel Name: atom-general
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C020VMT58JK - Channel Name: topics-data-analytics
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C0213MNH9L6 - Channel Name: topics-python
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C0213N56M2A - Channel Name: topics-materials
# ====> {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C021FSDN7LJ - Channel Name: atom-assignment2
# Channel ID: C021KLB0DSB - Channel Name: discuss-group3
# Channel ID: C021KLB90GP - Channel Name: discuss-group4
# Channel ID: C02204B2CD6 - Channel Name: atom-week2
# Channel ID: C0220KU9399 - Channel Name: discuss-group1
# Channel ID: C0226D3LEQ4 - Channel Name: atom-week3
# Channel ID: C0227A51SAY - Channel Name: atom-assignment3
# Channel ID: C022Q7TGRLG - Channel Name: discuss-group2
# Channel ID: C022RRWQ6US - Channel Name: atom-assignment4
# Channel ID: C022Y1FUETE - Channel Name: atom-week4
# Channel ID: C023UJGMDND - Channel Name: atom-assignment5
# Channel ID: C0245PZUFSL - Channel Name: atom-week5

# %%
msg_df = pd.DataFrame(msg_dict)
msg_df = msg_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
msg_df.tail()
# Out:
#       channel_id                                msg_id  \
# 229  C022Y1FUETE  38adf48f-21cc-437c-9ad3-31cd002bc4f8
# 230  C023UJGMDND  15096040-5001-4884-aeeb-92ee5bcad3e3
# 231  C023UJGMDND  a8edeb55-8d76-4ea7-8ea0-3111840ffb44
# 232  C0245PZUFSL  2ccae5b9-902c-4fff-bf08-e84d558537be
# 233  C0245PZUFSL  a6e46b2c-00a6-43f3-acb2-9fb221d25d4b
#
#                         msg_ts      user_id               latest_reply  \
# 229 2021-05-23 14:58:05.001500  U01BE2PR6LU 2021-05-23 23:15:45.002200
# 230 2021-06-02 17:34:22.003500  U01UTGT8CVA 1970-01-01 08:00:00.000000
# 231 2021-05-30 08:55:42.001400  U01BE2PR6LU 1970-01-01 08:00:00.000000
# 232 2021-06-02 19:10:03.003400  U01BE2PR6LU 1970-01-01 08:00:00.000000
# 233 2021-06-02 19:09:43.003200  U01BE2PR6LU 1970-01-01 08:00:00.000000
#
#      reply_user_count    reply_users                     github_link
# 229                 1  [U01VB632FPS]                             NaN
# 230                 0              0  https://github.com/ngttnguyen/
# 231                 0              0  https://github.com/anhdanggit/
# 232                 0              0                             NaN
# 233                 0              0                             NaN

# %%
dtc_groups = pd.read_csv('datacracy_groups.csv')
dtc_groups.head()
# Out:
#                 name DataCracy_role
# 0           slackbot            BTC
# 1     loclexuan26392            BTC
# 2           locle.ds            BTC
# 3     maianhdang.ftu            BTC
# 4  huyenhoang.design            BTC

# %%
user_df = pd.merge(user_df, dtc_groups, how="left", on=["name"])
user_df.head()
# Out:
#        user_id               name       display_name           real_name  \
# 0    USLACKBOT           slackbot           Slackbot            Slackbot
# 1  U01AT4T75JB     loclexuan26392        Loc Le Xuan         Loc Le Xuan
# 2  U01AVDY7JET           locle.ds        Loc Le Xuan         Loc Le Xuan
# 3  U01BE2PR6LU     maianhdang.ftu                MAD  Dặng Huỳnh Mai Anh
# 4  U01C48T7S1J  huyenhoang.design  Thanh Huyen Hoang   Thanh Huyen Hoang
#
#                 title  is_bot DataCracy_role
# 0                 NaN   False            BTC
# 1                 NaN   False            BTC
# 2                 NaN   False            BTC
# 3  Technical Contents   False            BTC
# 4                 NaN   False            BTC

# %%
# Code để upload data lên Gsheet
## Authorize bằng JSON
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(
    'QuanNguyen-b8bebb09be47.json', scope)
gc = gspread.authorize(credentials)
print("DONE!")
# Out:
# DONE!

# %%
sheets = ['user','channel','msg_channel']
df = [user_df,channel_df,msg_df]
spreadsheet_key = '1QeYCCDcvjAIA_NC-toMTKpZ_0dgwGRGF84PETQ0YJdE' # input SPREADSHEET_KEY HERE
sh = gc.open_by_key(spreadsheet_key)
for i in range(len(sheets)):
    worksheet = sh.get_worksheet(i)
    set_with_dataframe(worksheet, df[i])
    print('Done upload data with data {} at sheet {} on Googelspreadsheets'.format(sheets[i], df[i]))
# Out:
# Done upload data with data user at sheet         user_id                name       display_name           real_name  \
# 0     USLACKBOT            slackbot           Slackbot            Slackbot
# 1   U01AT4T75JB      loclexuan26392        Loc Le Xuan         Loc Le Xuan
# 2   U01AVDY7JET            locle.ds        Loc Le Xuan         Loc Le Xuan
# 3   U01BE2PR6LU      maianhdang.ftu                MAD  Dặng Huỳnh Mai Anh
# 4   U01C48T7S1J   huyenhoang.design  Thanh Huyen Hoang   Thanh Huyen Hoang
# ..          ...                 ...                ...                 ...
# 70  U022J0SQAMQ                 abc                NaN                 abc
# 71  U022R4885AN                  78                NaN                  78
# 72  U0233KHLM2M  vuthanhdat.contact                NaN  Vuthanhdat Contact
# 73  U023E0BAHQ8        testgettoken                NaN       test.gettoken
# 74  U023G7HDUL8                ass4                NaN                Ass4
#
#                  title  is_bot DataCracy_role
# 0                  NaN   False            BTC
# 1                  NaN   False            BTC
# 2                  NaN   False            BTC
# 3   Technical Contents   False            BTC
# 4                  NaN   False            BTC
# ..                 ...     ...            ...
# 70                 NaN    True            NaN
# 71                 NaN    True            NaN
# 72                 NaN   False    Learner_Gr4
# 73                 NaN    True            NaN
# 74                 NaN    True            NaN
#
# [75 rows x 7 columns] on Googelspreadsheets
# Done upload data with data channel at sheet      channel_id           channel_name  is_channel      creator  \
# 0   C01B4PVGLVB                general        True  U01BE2PR6LU
# 1   C01BYH7JHB5               contents        True  U01BE2PR6LU
# 2   C01CAMNCJJV        branding-design        True  U01AVDY7JET
# 3   C01U6P7LZ8F       atom-assignment1        True  U01BE2PR6LU
# 4   C01UL6K1C7L             atom-week1        True  U01BE2PR6LU
# 5   C01ULCHGN75           atom-general        True  U01BE2PR6LU
# 6   C020VMT58JK  topics-data-analytics        True  U01BE2PR6LU
# 7   C0213MNH9L6          topics-python        True  U01BE2PR6LU
# 8   C0213N56M2A       topics-materials        True  U01BE2PR6LU
# 9   C021FSDN7LJ       atom-assignment2        True  U01BE2PR6LU
# 10  C021KLB0DSB         discuss-group3        True  U01BE2PR6LU
# 11  C021KLB90GP         discuss-group4        True  U01BE2PR6LU
# 12  C02204B2CD6             atom-week2        True  U01BE2PR6LU
# 13  C0220KU9399         discuss-group1        True  U01BE2PR6LU
# 14  C0226D3LEQ4             atom-week3        True  U01BE2PR6LU
# 15  C0227A51SAY       atom-assignment3        True  U01BE2PR6LU
# 16  C022Q7TGRLG         discuss-group2        True  U01BE2PR6LU
# 17  C022RRWQ6US       atom-assignment4        True  U01BE2PR6LU
# 18  C022Y1FUETE             atom-week4        True  U01BE2PR6LU
# 19  C023UJGMDND       atom-assignment5        True  U01BE2PR6LU
# 20  C0245PZUFSL             atom-week5        True  U01BE2PR6LU
#
#             created_at                                             topics  \
# 0  2020-09-23 17:25:03                                                NaN
# 1  2020-10-05 14:28:09                                                NaN
# 2  2020-10-05 10:16:30                                                NaN
# 3  2021-04-17 14:00:04  Assigment#1 - Python Basics &amp; Spreadsheet ...
# 4  2021-04-17 00:44:32  TOPIC: Data Strategy. Metrics Design. Spreadsh...
# 5  2021-04-17 00:42:20              General communication channel of ATOM
# 6  2021-05-08 13:05:40                                                NaN
# 7  2021-05-08 13:05:21                                                NaN
# 8  2021-05-08 13:31:38                                                NaN
# 9  2021-05-11 03:05:42          Assigment#2 - Mailbot, API, Web Scrapping
# 10 2021-05-15 13:42:51                                                NaN
# 11 2021-05-15 13:43:22                                                NaN
# 12 2021-05-08 08:45:22                     TOPIC: Python Basics &amp; Git
# 13 2021-05-15 13:42:04                                                NaN
# 14 2021-05-15 09:00:45           TOPIC: API, JSON, Mailbot, Web Scrapping
# 15 2021-05-16 07:39:33                                                NaN
# 16 2021-05-15 13:42:25                                                NaN
# 17 2021-05-23 06:21:49                                                NaN
# 18 2021-05-23 06:33:45                                                NaN
# 19 2021-05-30 08:54:00                                                NaN
# 20 2021-05-30 08:58:41                                                NaN
#
#                                               purpose  num_members
# 0   This is the one channel that will always inclu...           64
# 1                                                 NaN           12
# 2                                                 NaN            9
# 3   Where learners submit assignments and give rev...           44
# 4   TOPIC: Data Strategy. Metrics Design. Spreadsh...           43
# 5               General communication channel of ATOM           24
# 6                                                 NaN           18
# 7                      Channel để thảo luận về Python           32
# 8                                                 NaN           22
# 9   Where learners submit assignments and give rev...           40
# 10                           Group 3 Discussion Space           13
# 11                           Group 4 Discussion Space           14
# 12         Data tools (2): Github &amp; Python Basics           26
# 13                           Group 1 Discussion Space           11
# 14                                                NaN           26
# 15                                                NaN           38
# 16                           Group 2 Discussion Space           13
# 17            Submisstion + Review Space Assignment#4           36
# 18                   Discuss nội dung và assignment 4           17
# 19                                                NaN           24
# 20                                                NaN           14   on Googelspreadsheets
# Done upload data with data msg_channel at sheet       channel_id                                msg_id  \
# 0    C01U6P7LZ8F  005AD620-BD06-4123-BC42-6118DAA73BA4
# 1    C01U6P7LZ8F  D86A48D2-D953-4504-92BF-D9240B2549A8
# 2    C01U6P7LZ8F  246fb20c-8739-4664-9bcf-14f57aee17f7
# 3    C01U6P7LZ8F  4214088f-ccdc-4e8e-9c19-677ae3f439a1
# 4    C01U6P7LZ8F  cfad12f7-bf9c-4209-b563-f495f378fb1f
# ..           ...                                   ...
# 229  C022Y1FUETE  38adf48f-21cc-437c-9ad3-31cd002bc4f8
# 230  C023UJGMDND  15096040-5001-4884-aeeb-92ee5bcad3e3
# 231  C023UJGMDND  a8edeb55-8d76-4ea7-8ea0-3111840ffb44
# 232  C0245PZUFSL  2ccae5b9-902c-4fff-bf08-e84d558537be
# 233  C0245PZUFSL  a6e46b2c-00a6-43f3-acb2-9fb221d25d4b
#
#                         msg_ts      user_id               latest_reply  \
# 0   2021-05-13 21:09:48.011000  U01UTGRMGEQ 2021-05-14 01:01:34.021400
# 1   2021-05-10 11:51:46.004700  U01UJ9LG5U5 2021-05-15 16:14:31.003600
# 2   2021-05-10 11:35:39.003800  U01UMC08KL2 2021-05-18 15:09:59.000800
# 3   2021-05-10 10:07:35.001200  U01UTGRQS9J 2021-05-15 16:28:16.004000
# 4   2021-05-08 13:43:25.006900  U01BE2PR6LU 1970-01-01 08:00:00.000000
# ..                         ...          ...                        ...
# 229 2021-05-23 14:58:05.001500  U01BE2PR6LU 2021-05-23 23:15:45.002200
# 230 2021-06-02 17:34:22.003500  U01UTGT8CVA 1970-01-01 08:00:00.000000
# 231 2021-05-30 08:55:42.001400  U01BE2PR6LU 1970-01-01 08:00:00.000000
# 232 2021-06-02 19:10:03.003400  U01BE2PR6LU 1970-01-01 08:00:00.000000
# 233 2021-06-02 19:09:43.003200  U01BE2PR6LU 1970-01-01 08:00:00.000000
#
#      reply_user_count                                        reply_users  \
# 0                   4  [U01V00P4S2V, U01UTGRMGEQ, U01UMJ451V1, U01V00...
# 1                   2                         [U01USGKQ771, U01V00KHHHP]
# 2                   2                         [U01UTGS5ZNY, U01UMC08KL2]
# 3                   2                         [U01VB632FPS, U01V00KHHHP]
# 4                   0                                                  0
# ..                ...                                                ...
# 229                 1                                      [U01VB632FPS]
# 230                 0                                                  0
# 231                 0                                                  0
# 232                 0                                                  0
# 233                 0                                                  0
#
#                           github_link
# 0                                 NaN
# 1         https://github.com/danhpcv/
# 2    https://github.com/auslynnguyen/
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 229                               NaN
# 230    https://github.com/ngttnguyen/
# 231    https://github.com/anhdanggit/
# 232                               NaN
# 233                               NaN
#
# [234 rows x 8 columns] on Googelspreadsheets

# %% [markdown]
# Link Googelspreadsheets: [Googelspreadsheets](https://docs.google.com/spreadsheets/d/1QeYCCDcvjAIA_NC-toMTKpZ_0dgwGRGF84PETQ0YJdE/edit?usp=sharing)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # TODO 2: Python Pandas
# [Kaggle](https://www.kaggle.com/) là cộng đồng lớn nhất thế giới về Data Science với các cuộc thi/thử thách ML, các công cụ và tài liệu để học và phát triển kỹ năng
# * Tạo account của bạn trên Kaggle
# * Coi tutorial và làm 6 sets bài tập trên Kaggle [HERE](https://www.kaggle.com/learn/pandas)
# * Bạn có thể làm bài trực tiếp trên Kaggle (cũng là dạng notebook online như Colab). Toàn bộ notebook sẽ lưu trên phần Code trong Profile Account của bạn
# ![image.png](data:image/png;base64,...)

# %%
# Copy các link Kaggle sau:
## 1. Link tới Kaggle Account của bạn -----> 
## 2. Link tới các bài tập
## Pandas 1: ---> https://www.kaggle.com/quan030894/exercise-creating-reading-and-writing
## Pandas 2: ---> https://www.kaggle.com/quan030894/exercise-indexing-selecting-assigning
## Pandas 3: ---> https://www.kaggle.com/quan030894/exercise-summary-functions-and-maps
## Pandas 4: ---> https://www.kaggle.com/quan030894/exercise-grouping-and-sorting
## Pandas 5: ---> https://www.kaggle.com/quan030894/exercise-data-types-and-missing-values
## Pandas 6: ---> https://www.kaggle.com/quan030894/exercise-renaming-and-combining

# %% [markdown]
# # TODO 3: Python Pandas
# Trở lại TODO7 [Assignment#4](https://github.com/anhdanggit/atom-assignments/blob/main/assignment_4/home_assignment_4.ipynb) (nếu bạn chưa hoàn thành)

# %% [markdown]
# - Đã hoàn thành ở phần [Assignment#4](https://github.com/Quan030994/atom-assignments/tree/main/assignment_4) mời bạn xem ở link và góp ý giúp nhé. Cảm ơn!

# %% [markdown]
# # TODO 4 (OPTIONAL): Python Data Viz
# Coi tutorial và làm nhiều nhất có thể các sets bài tập trên [Kaggle Data Visualization](https://www.kaggle.com/learn/data-visualization)

# %%
# Copy Link tới các bài tập
## DataViz 1: ---> https://www.kaggle.com/quan030894/exercise-hello-seaborn
## DataViz 2: ---> https://www.kaggle.com/quan030894/exercise-line-charts
## DataViz 3: ---> https://www.kaggle.com/quan030894/exercise-bar-charts-and-heatmaps
## DataViz 4: ---> https://www.kaggle.com/quan030894/exercise-scatter-plots
## DataViz 5: ---> https://www.kaggle.com/quan030894/exercise-distributions
## DataViz 6: ---> https://www.kaggle.com/quan030894/exercise-choosing-plot-types-and-custom-styles
## DataViz 7: ---> https://www.kaggle.com/quan030894/exercise-final-project
